# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import json
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'local', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database

# %%
# assign the collection to a variable
establishments = db["establishments"]

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20


# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint


query = {"scores.Hygiene": 20}
results = establishments.find(query)
documents = list(results)
count = establishments.count_documents(query)
print("Number of documents with a hygiene score of 20:", count)
pprint(documents[0])
# Out:
# Number of documents with a hygiene score of 20: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6426507bd7a9bd925a3177a9'),
#  'geocode': {'latitude': None, 'longitude': None},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(documents)
# Display the number of rows in the DataFrame
print(len(df))

df.head(10)
# Display the first 10 rows of the DataFrame
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6426507bd7a9bd925a3177a9   110681                  0
# 1  6426507cd7a9bd925a317b2a   612039                  0
# 2  6426507cd7a9bd925a317e34   730933                  0
# 3  6426507cd7a9bd925a318022   172735                  0
# 4  6426507cd7a9bd925a318031   172953                  0
# 5  6426507dd7a9bd925a3189d0   512854                  0
# 6  6426507dd7a9bd925a318bf1  1537089                  0
# 7  6426507ed7a9bd925a31a11c   155648                  0
# 8  6426507fd7a9bd925a31a560  1012883                  0
# 9  6426507fd7a9bd925a31ad72   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                  geocode RightToReply     Distance  \
# 0  {'longitude': None, 'latitude': None}               4613.888288
# 1  {'longitude': None, 'latitude': None}               4617.965824
# 2  {'longitude': None, 'latitude': None}               4619.656144
# 3  {'longitude': None, 'latitude': None}               4620.421725
# 4  {'longitude': None, 'latitude': None}               4620.437179
# 5  {'longitude': None, 'latitude': None}               4625.565258
# 6  {'longitude': None, 'latitude': None}               4626.200132
# 7  {'longitude': None, 'latitude': None}               4632.276890
# 8  {'longitude': None, 'latitude': None}               4633.934041
# 9  {'longitude': None, 'latitude': None}               4636.552523
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"AddressLine3": {"$regex": "London"}, "RatingValue": {"$gte": 4}}
results = establishments.find(query)


for result in results:
    print(result)
# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint

# %%
query = {"AddressLine3": "London", "$expr": {"$gte": [{"$toInt": "$RatingValue"}, 4]}}
results = establishments.find(query)

count = establishments.count_documents({})
print("Number of documents:", count)
# Out:
# Number of documents: 38788

# %%
# Convert the result to a Pandas DataFrame
query = {"AddressLine3": "London", "$expr": {"$gte": [{"$toInt": "$RatingValue"}, 4]}}

results = establishments.find(query)
df = pd.DataFrame(list(results))

print("Number of rows in DataFrame:", len(df))
print("First 10 rows of DataFrame:")
print(df.head(10))
# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15364\2734485673.py in <module>
#       3
#       4 results = establishments.find(query)
# ----> 5 df = pd.DataFrame(list(results))
#       6
#       7 print("Number of rows in DataFrame:", len(df))
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1246         if self.__empty:
#    1247             raise StopIteration
# -> 1248         if len(self.__data) or self._refresh():
#    1249             return self.__data.popleft()
#    1250         else:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1163                 self.__exhaust,
#    1164             )
# -> 1165             self.__send_message(q)
#    1166         elif self.__id:  # Get More
#    1167             if self.__limit:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#    1050
#    1051         try:
# -> 1052             response = client._run_operation(
#    1053                 operation, self._unpack_response, address=self.__address
#    1054             )
#
# ~\anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1328             )
#    1329
# -> 1330         return self._retryable_read(
#    1331             _cmd,
#    1332             operation.read_preference,
#
# ~\anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1446                         assert last_error is not None
#    1447                         raise last_error
# -> 1448                     return func(session, server, sock_info, read_pref)
#    1449             except ServerSelectionTimeoutError:
#    1450                 if retrying:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1324         def _cmd(session, server, sock_info, read_preference):
#    1325             operation.reset()  # Reset op in case of retry.
# -> 1326             return server.run_operation(
#    1327                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1328             )
#
# ~\anaconda3\lib\site-packages\pymongo\server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     132                 first = docs[0]
#     133                 operation.client._process_response(first, operation.session)
# --> 134                 _check_command_response(first, sock_info.max_wire_version)
#     135         except Exception as exc:
#     136             if publish:
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     179         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     180
# --> 181     raise OperationFailure(errmsg, code, response, max_wire_version)
#     182
#     183
#
# OperationFailure: Executor error during find command :: caused by :: Failed to parse number 'AwaitingInspection' in $convert with no onError value: Did not consume whole string., full error: {'ok': 0.0, 'errmsg': "Executor error during find command :: caused by :: Failed to parse number 'AwaitingInspection' in $convert with no onError value: Did not consume whole string.", 'code': 241, 'codeName': 'ConversionFailure'}

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
